# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\YASH-
# [nltk_data]     SHIVGAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\YASH-
# [nltk_data]     SHIVGAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import wordnet as wn

# Sample text
text = "The dog is a loyal animal. It is very faithful and good."

# Tokenize manually (simple split)
words = text.lower().replace(".", "").split()

# Function to get semantic relationships
def get_semantic_relations(word):
    synonyms = set()
    antonyms = set()
    hypernyms = set()
    
    synsets = wn.synsets(word)
    
    for syn in synsets:
        # Synonyms
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
            
            # Antonyms
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
        
        # Hypernyms
        for hyper in syn.hypernyms():
            hypernyms.add(hyper.name().split('.')[0])
    
    return synonyms, antonyms, hypernyms


# Process each word
for word in words:
    synonyms, antonyms, hypernyms = get_semantic_relations(word)
    
    if synonyms:
        print("\nWord:", word)
        print("Synonyms:", synonyms)
        print("Antonyms:", antonyms)
        print("Hypernyms:", hypernyms)
# Out:
# Word: dog
# Synonyms: {'bounder', 'hotdog', 'domestic_dog', 'cad', 'click', 'pawl', 'wiener', 'firedog', 'go_after', 'chase_after', 'hound', 'tail', 'heel', 'dog-iron', 'frankfurter', 'hot_dog', 'tag', 'frank', 'andiron', 'frump', 'trail', 'give_chase', 'detent', 'track', 'weenie', 'chase', 'dog', 'Canis_familiaris', 'wienerwurst', 'blackguard'}
# Antonyms: set()
# Hypernyms: {'villain', 'canine', 'domestic_animal', 'pursue', 'chap', 'catch', 'unpleasant_woman', 'sausage', 'support'}
#
# Word: is
# Synonyms: {'equal', 'constitute', 'be', 'cost', 'exist', 'represent', 'embody', 'make_up', 'follow', 'personify', 'live', 'comprise'}
# Antonyms: {'differ'}
# Hypernyms: {'typify', 'take', 'be', 'stay'}
#
# Word: a
# Synonyms: {'type_A', 'angstrom', 'A', 'vitamin_A', 'deoxyadenosine_monophosphate', 'group_A', 'angstrom_unit', 'ampere', 'amp', 'antiophthalmic_factor', 'axerophthol', 'adenine', 'a'}
# Antonyms: set()
# ...

# %%
import nltk
from nltk.corpus import wordnet as wn

text = "The brave soldier fought courageously in the dangerous battle."

# Tokenize manually (simple split)
words = text.lower().replace(".", "").split()

# Function to get semantic relationships
def get_semantic_relations(word):
    synonyms = set()
    antonyms = set()
    hypernyms = set()
    
    synsets = wn.synsets(word)
    
    for syn in synsets:
        # Synonyms
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
            
            # Antonyms
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
        
        # Hypernyms
        for hyper in syn.hypernyms():
            hypernyms.add(hyper.name().split('.')[0])
    
    return synonyms, antonyms, hypernyms


# Process each word
for word in words:
    synonyms, antonyms, hypernyms = get_semantic_relations(word)
    
    if synonyms:
        print("\nWord:", word)
        print("Synonyms:", synonyms)
        print("Antonyms:", antonyms)
        print("Hypernyms:", hypernyms)
# Out:
# Word: brave
# Synonyms: {'brave_out', 'endure', 'courageous', 'intrepid', 'fearless', 'weather', 'braw', 'unfearing', 'brave', 'audacious', 'gay', 'hardy', 'dauntless'}
# Antonyms: {'cowardly', 'timid'}
# Hypernyms: {'warrior', 'people', 'defy'}
#
# Word: soldier
# Synonyms: {'soldier'}
# Antonyms: set()
# Hypernyms: {'enlisted_person', 'spend', 'worker'}
#
# Word: fought
# Synonyms: {'contend', 'struggle', 'defend', 'press', 'push', 'fight_back', 'crusade', 'agitate', 'oppose', 'fight_down', 'campaign', 'fight'}
# Antonyms: set()
# Hypernyms: {'try', 'contend', 'advertise'}
#
# Word: courageously
# Synonyms: {'courageously', 'bravely'}
# Antonyms: set()
# Hypernyms: set()
#
# Word: in
# Synonyms: {'in', 'atomic_number_49', 'IN', 'inch', 'indium', 'Indiana', 'inwards', 'Hoosier_State', 'In', 'inward'}
# Antonyms: set()
# Hypernyms: {'metallic_element', 'linear_unit'}
#
# Word: dangerous
# Synonyms: {'dangerous', 'grievous', 'serious', 'severe', 'life-threatening', 'unsafe', 'grave'}
# ...

# %%
import nltk
from nltk.corpus import wordnet as wn

text = "Exercise keeps the body strong and healthy. It prevents illness and weakness."
# Tokenize manually (simple split)
words = text.lower().replace(".", "").split()

# Function to get semantic relationships
def get_semantic_relations(word):
    synonyms = set()
    antonyms = set()
    hypernyms = set()
    
    synsets = wn.synsets(word)
    
    for syn in synsets:
        # Synonyms
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
            
            # Antonyms
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
        
        # Hypernyms
        for hyper in syn.hypernyms():
            hypernyms.add(hyper.name().split('.')[0])
    
    return synonyms, antonyms, hypernyms


# Process each word
for word in words:
    synonyms, antonyms, hypernyms = get_semantic_relations(word)
    
    if synonyms:
        print("\nWord:", word)
        print("Synonyms:", synonyms)
        print("Antonyms:", antonyms)
        print("Hypernyms:", hypernyms)
# Out:
# Word: exercise
# Synonyms: {'usage', 'physical_exertion', 'do', 'practice', 'utilization', 'use', 'employment', 'exercising', 'example', 'physical_exercise', 'exert', 'drill', 'work', 'workout', 'practise', 'exercise', 'practice_session', 'work_out', 'utilisation', 'recitation'}
# Antonyms: set()
# Hypernyms: {'ceremony', 'training', 'learn', 'use', 'work', 'activity', 'lesson', 'effort'}
#
# Word: keeps
# Synonyms: {'observe', 'keep_on', 'hold_back', 'keep_open', 'maintain', 'restrain', 'retain', 'bread_and_butter', 'proceed', 'donjon', 'celebrate', 'hold', 'prevent', 'dungeon', 'go_along', 'stay_fresh', 'sustain', 'hold_on', 'support', 'hold_open', 'save', 'keep', 'living', 'preserve', 'sustenance', 'go_on', 'keep_back', 'livelihood', 'continue'}
# Antonyms: {'discontinue', 'let', 'break', 'lose'}
# Hypernyms: {'resource', 'have', 'prolong', 'protect', 'cell', 'record', 'stay', 'reserve', 'store', 'stronghold', 'grow', 'cook', 'inhibit', 'confine', 'act', 'lodge'}
#
# Word: body
# ...
